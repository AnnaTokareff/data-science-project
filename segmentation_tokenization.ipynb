# %% [markdown]
# # 2.1 Sentence Segmentation

# %% [markdown]
# Here I will compare two libraries: Stanza and Spacy. The code will provide with following information:
# * Total number of sentences in the parsed data
# * Number of sentences recognized by Spacy
# * Number of sentences recognized by Stanza
# * Number of shared sentences

# %%
import spacy
import stanza
import pandas as pd
import numpy as np
import nltk
import string
import collections
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /Users/anna/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("part2_dataset.csv")

# %%
df
# Out:
#                                                 texts
# 0   Some notable French Huguenots or people with F...
# 1   Abel Boyer (1667? – 16 November 1729) was a Fr...
# 2   Abolitionism, or the abolitionist movement, is...
# 3   In the United States, abolitionism, the moveme...
# 4   Abraham Bosse (c. 1604 – 14 February 1676) was...
# 5   Abraham Faure (29 August 1795 – 28 March 1875)...
# 6   Jean Humbert de Superville (Amsterdam, 7 May 1...
# 7   Some notable French Huguenots or people with F...
# 8   Some notable French Huguenots or people with F...
# 9   Abraham Mazel (5 September 1677 – 17 October 1...
# 10  Abraham Salle (1670–ca. 1719) was a French Hug...
# 11  Mandela and de Klerk is a 1997 made-for-televi...
# 12  Abraham de Moivre FRS (French pronunciation: ​...
# 13  Adolf Josef Ferdinand Galland (19 March 1912 –...
# 14  Adolph Gysbert Malan,  (3 October 1910 – 17 Se...
# 15  Adolph Friedrich Erdmann von Menzel (8 Decembe...
# 16  Adolphe-Louis-Frédéric-Théodore Monod (21 Janu...
# 17  Blignaut is an Afrikaans surname, derived from...
# 18  Théodore-Agrippa d'Aubigné (French pronunciati...
# 19  Alain Bombard (French pronunciation: ​[alɛ̃ bɔ...
# 20  Alain Marie Juppé (French pronunciation: ​[alɛ...
# 21  Rev. Albert Rivett (17 May 1855 – 18 November ...
# 22  Albert Réville (4 November 1826, Dieppe, Seine...
# 23  Ludwig Philipp Albert Schweitzer  (German: [ˈa...
# 24  Albert Thibaudet (1 April 1874 in Tournus, Saô...
# 25  Alexander Hamilton (January 11, 1755 or 1757 –...
# 26  Alexander Logie du Toit FRS ( doo-TOY; 14 Marc...
# 27  Friedrich Wilhelm Heinrich Alexander von Humbo...
# 28  Alexandre Olivier Exquemelin (also spelled Esq...
# 29  Alexandre Rodolphe Vinet (17 June 1797 – 4 May...
# 30  Alexis Benoît Soyer (4 February 1810 – 5 Augus...
# 31  Alfred Ainger (9 February 1837 – 8 February 19...
# 32  Some notable French Huguenots or people with F...
# 33  Alfred Irénée du Pont (May 12, 1864 – April 28...
# 34  Alfred George Gardyne de Chastelain, DSO, OBE ...
# 35  Alice Cooper (born Vincent Damon Furnier, Febr...
# 36  Alonzo Garcelon (May 6, 1813 – December 8, 190...
# 37  Some notable French Huguenots or people with F...
# 38  Ambroise Paré (c. 1510 – 20 December 1590) was...
# 39  The American Civil War (April 12, 1861 – May 2...
# 40  The American Revolutionary War (April 19, 1775...
# 41  The American Revolutionary War (April 19, 1775...
# 42  Ampie Du Preez (born c. 1982) is a South Afric...
# 43  Amyraldism (sometimes Amyraldianism) is a Calv...
# 44  Andrew Coltée Ducarel  (9 June 1713 – 29 May 1...
# 45  Faneuil Hall ( or ; previously ) is a marketpl...
# 46  Andrew Le Mercier (1692-1764) was French-born ...
# 47  Andrew James Clutterbuck (born 14 September 19...
# 48  Andrew Lortie (or André Lortie) was a leading ...
# 49  Andrew Murray (9 May 1828 – 18 January 1917) w...

# %%
def sentence_segmentation(df):
    
    '''
    performs sentence segmentation,
    calculates the number of sentences in the text according to stanza and spacy,
    finds the shared sentences between stanza and spacy,
    finds the unique sentences for stanza and spacy,
    
    '''
    
    nlp1 = stanza.Pipeline(lang='en', processors='tokenize')
    nlp2 = spacy.load('en_core_web_sm')
    
    df['sentences_stanza'] = df['texts'].apply(lambda x: [sentence.text for sentence in nlp1(x).sentences])
    df['sentences_spacy'] = df['texts'].apply(lambda x: [sentence.text for sentence in nlp2(x).sents])
    df['num_sentences_stanza'] = df['sentences_stanza'].apply(len) # number of sentences in the text according to stanza
    df['num_sentences_spacy'] = df['sentences_spacy'].apply(len) # number of sentences in the text according to spacy
    
    
    shared_sentences = set() # set of shared sentences
    unique_sentences_stanza = set() # set of unique sentences for stanza
    unique_sentences_spacy = set() # set of unique sentences for spacy
    
    for i in range(len(df)):
        
        shared_sentences.update(set(df['sentences_stanza'][i]).intersection(set(df['sentences_spacy'][i])))  # intersection of sentences
        unique_sentences_stanza.update(set(df['sentences_stanza'][i]).difference(set(df['sentences_spacy'][i])))
        unique_sentences_spacy.update(set(df['sentences_spacy'][i]).difference(set(df['sentences_stanza'][i])))
        
    df['unique_sent_stanza'] = pd.Series(list(unique_sentences_stanza))
    df['unique_sent_spacy'] = pd.Series(list(unique_sentences_spacy))  
      
    SharedSentences = pd.DataFrame({"shared_sentences": list(shared_sentences)})
    SharedSentences.to_csv("shared_sentences.csv", index=False)
    df.to_csv("part2_processed_dataset.csv", index=False)
    
    
    print("--------" * 10)
    print("Total number of sentences in the dataset: ", df['num_sentences_stanza'].sum() + df['num_sentences_spacy'].sum())
    print("Number of sentences in the text according to stanza: ", df['num_sentences_stanza'].sum())
    print("Number of sentences in the text according to spacy: ", df['num_sentences_spacy'].sum())
    print("Number of shared sentences: ", len(shared_sentences))
    print("Number of unique sentences for stanza: ", len(unique_sentences_stanza))
    print("Number of unique sentences for spacy: ", len(unique_sentences_spacy))
        
    return df, SharedSentences

# %%
#!python -m spacy download en_core_web_sm

# %%
df, shared_sent_def = sentence_segmentation(df)
# Out:
# 2023-05-14 04:32:44 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 22.3MB/s]
# 2023-05-14 04:32:44 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2023-05-14 04:32:44 INFO: Using device: cpu
# 2023-05-14 04:32:44 INFO: Loading: tokenize
# 2023-05-14 04:32:44 INFO: Done loading processors!
# --------------------------------------------------------------------------------
# Total number of sentences in the dataset:  31281
# Number of sentences in the text according to stanza:  15943
# Number of sentences in the text according to spacy:  15338
# Number of shared sentences:  4740
# Number of unique sentences for stanza:  3786
# Number of unique sentences for spacy:  3406

# %%
shared_sent_def
# Out:
#                                        shared_sentences
# 0     An attempt to resupply the fort on January 9, ...
# 1     The second was a civil war with all thirteen s...
# 2     The Grimké sisters' public speaking played a c...
# 3     The debates were covered in detail by American...
# 4     Galland was upset about the director's decisio...
# ...                                                 ...
# 4735  Charles-Édouard Babut (1835-1916), pastor, Nîmes.
# 4736  Instead, the fighter force was committed to th...
# 4737  Knowlton's Rangers, which included Nathan Hale...
# 4738  Benjamin Franklin and James Madison each helpe...
# 4739  In November 1792, James Reynolds and his assoc...
#
# [4740 rows x 1 columns]

# %% [markdown]
# # 2.2 Tokenization

# %% [markdown]
# ### In this part we will compare tokens which appear firtst in texts without segmentation and then - with segmentation.

# %% [markdown]
# ### 2.2.1 SharedTokensNoSentences
#
# Here we will need our preprocessing function again.

# %%
def preprocess(tokens_list, remove_stop_words=True):
    
    """ 
    removes non-ASCII chars, performs tokenization, lowercases the tokens,
    delete stopwords, punctuation and non-alphabetical characters,
    converts tokens to normal form
    
    """
    tokens = [token.lower() for token in tokens_list] # lowercase
    tokens = [token for token in tokens if token not in string.punctuation] # remove punctuation
    tokens = [token for token in tokens if token.isalpha()] # remove non-alphabetical characters
    
    if remove_stop_words:
        tokens = [token for token in tokens if token not in stop_words] # remove stopwords

    lemmatizer = WordNetLemmatizer()  
    tokens = [lemmatizer.lemmatize(token) for token in tokens] # convert to normal form

    return tokens

# %%
df = pd.read_csv("part2_processed_dataset.csv")
df.head(5)
# Out:
#                                                texts
# 0  Some notable French Huguenots or people with F...  \
# 1  Abel Boyer (1667? – 16 November 1729) was a Fr...
# 2  Abolitionism, or the abolitionist movement, is...
# 3  In the United States, abolitionism, the moveme...
# 4  Abraham Bosse (c. 1604 – 14 February 1676) was...
#
#                                     sentences_stanza
# 0  ['Some notable French Huguenots or people with...  \
# 1  ['Abel Boyer (1667? – 16 November 1729) was a ...
# 2  ['Abolitionism, or the abolitionist movement, ...
# 3  ['In the United States, abolitionism, the move...
# 4  ['Abraham Bosse (c.\u20091604 – 14 February 16...
#
#                                      sentences_spacy  num_sentences_stanza
# 0  ['Some notable French Huguenots or people with...                  1642  \
# 1  ['Abel Boyer (1667? – 16 November 1729) was a ...                    54
# 2  ['Abolitionism, or the abolitionist movement, ...                   332
# 3  ['In the United States, abolitionism, the move...                   545
# 4  ['Abraham Bosse (c.\u20091604 – 14 February 16...                    65
#
#    num_sentences_spacy                                 unique_sent_stanza
# 0                 1630                        Jean Jacques Favre, pastor.  \
# 1                   51  Glen Buxton said he could listen to Barrett's ...
# 2                  302  Francis Durand, convert from Roman Catholicism...
# 3                  518  Renaud (1952-), pop-rock singer, anti-military...
# 4                   75  Charles Chauvel (1897–1959), Australian film-m...
#
#                                    unique_sent_spacy
# 0  Antoine Barnave (1761-1783), French revolution...
# 1              [The psychiatric evaluation of Jesus.
# 2  Faneuil hall and Faneuil Hall Market: or, Pete...
# 3  Michael Pertwee (1916-1991), playwright and sc...
# 4       Ludwig Devrient (1784–1832), German actor.\n

# %%
import spacy
import stanza

def tokenization_before_segmentation(df):
    
    nlp1 = stanza.Pipeline(lang='en', processors='tokenize') # stanza
    df['tokens_stanza'] = df['texts'].apply(lambda x: [token.text for sentence in nlp1(x).sentences for token in sentence.tokens])
    
    nlp2 = spacy.load('en_core_web_sm') # spacy
    df['tokens_spacy'] = df['texts'].apply(lambda x: [token.text for token in nlp2(x)])
    
    # preprocess our tokens
    df['tokens_stanza'] = df['tokens_stanza'].apply(preprocess) 
    df['tokens_spacy'] = df['tokens_spacy'].apply(preprocess)
    
    df["tokens_occurence_stanza"] = df["tokens_stanza"].apply(lambda x: collections.Counter(x)) # tokens occurence for stanza
    df["tokens_occurence_spacy"] = df["tokens_spacy"].apply(lambda x: collections.Counter(x)) # tokens occurence for spacy
    
    # creating vocabularies of unique tokens for each library
    vocab_stanza = set(token for tokens in df['tokens_stanza'] for token in tokens)
    vocab_spacy = set(token for tokens in df['tokens_spacy'] for token in tokens)
    
    # tokens which simalteneously present in both vocabularies
    both_vocab_tokens = vocab_stanza.intersection(vocab_spacy)
    
    # all tokens which present in both vocabularies
    common_tokens_stanza = vocab_stanza.union(vocab_spacy)
    
    only_spacy_tokens = vocab_spacy.difference(vocab_stanza)
    only_stanza_tokens = vocab_stanza.difference(vocab_spacy)
    
    print("-----------------" * 10)
    print("Number of tokens in the vocabulary of stanza: ", len(vocab_stanza))
    print("STANZA TOKENS\n", vocab_stanza) 
    
    print("-----------------" * 10)
    print("Number of tokens in the vocabulary of spacy: ", len(vocab_spacy))
    print("SPACY TOKENS\n", vocab_spacy)
    
    print("-----------------" * 10)
    print("Number of tokens in the vocabulary of both libraries: ", len(both_vocab_tokens))
    print("Tokens in the vocabulary of both libraries\n", both_vocab_tokens)
    
    print("-----------------" * 10)
    print("Number of all tokens: ", len(common_tokens_stanza))
    print("All tokens\n", common_tokens_stanza)
    
    print("-----------------" * 10)
    print("Number of tokens that only in the vocabulary of stanza: ", len(only_stanza_tokens))
    print("UNIQUE FOR STANZA", only_stanza_tokens)
    
    print("-----------------" * 10)
    print("Number of tokens that only in the vocabulary of spacy: ", len(only_spacy_tokens))
    print("UNIQUE FOR SPACY", only_spacy_tokens)
    
    
    print("-----------------" * 10)
    print("Top 30 most common tokens for stanza", df["tokens_occurence_stanza"].sum().most_common(30))
    
    print("-----------------" * 10)
    print("Top 30 most common tokens for spacy", df["tokens_occurence_spacy"].sum().most_common(30))
    
    return df

# %%
df = tokenization_before_segmentation(df)
df.head(5)
df.to_csv("tokenization_before_segmentation.csv", index=False)
# Out:
# 2023-05-14 04:36:20 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 24.1MB/s]
# 2023-05-14 04:36:20 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2023-05-14 04:36:20 INFO: Using device: cpu
# 2023-05-14 04:36:20 INFO: Loading: tokenize
# 2023-05-14 04:36:20 INFO: Done loading processors!
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens in the vocabulary of stanza:  15382
# STANZA TOKENS
#  {'originator', 'mainly', 'sweden', 'seller', 'technocrat', 'rothe', 'mazel', 'doumergue', 'delano', 'watt', 'exist', 'joining', 'pictorial', 'planningchanges', 'decommissioned', 'infrastructure', 'miserable', 'matthew', 'jessie', 'günther', 'typical', 'blindness', 'eisengold', 'demonstrates', 'moscova', 'valdo', 'moral', 'defensive', 'necessitating', 'philanthropic', 'guiding', 'visuals', 'something', 'architectural', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'bhagavad', 'konstanze', 'possibly', 'criollo', 'considered', 'theologian', 'mouvement', 'miscellany', 'mythological', 'alarmed', 'contract', 'financing', 'duchy', 'fetishism', 'applicable', 'jew', 'showmanship', 'liger', 'advocate', 'chatelain', 'hatt', 'gastigny', 'volunteered', 'killed', 'constipation', 'phoned', 'steady', 'invokes', 'existed', 'diego', 'workmanship', 'drunk', 'tributary', 'golf', 'hospitalised', 'penitent', 'schipper', 'cazenove', 'detroit', 'clooney', 'allied', 'miscarriage', 'video', 'regarded', 'antisemitism', 'hammett', 'manières', 'priority', 'impressionism', 'eradicate', 'frankenstein', 'gregson', 'clement', 'istoric', 'deed', 'murder', 'estrangement', 'official', 'lag', 'iberia', 'aerial', 'asphyxiation', 'hierarchy', 'wish', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'rearrangement', 'commentary', 'greenback', 'stepdaughter', 'felony', 'competing', 'feux', 'laroon', 'königsberg', 'chabrol', 'besides', 'filming', 'displeasure', 'greatest', 'opposite', 'analyze', 'pierre', 'setback', 'resurrected', 'pavilion', 'bischoff', 'sandra', 'durham', 'polity', 'pettigrew', 'heath', 'anticipate', 'selig', 'sub', 'ambrose', 'tie', 'equaled', 'charmes', 'combat', 'commonly', 'impartial', 'hold', 'walter', 'aurélie', 'marchand', 'soberingly', 'peugeot', 'meanwhile', 'storm', 'retracted', 'japanese', 'eugenie', 'chevalier', 'efficiently', 'journal', 'expense', 'failure', 'evaluation', 'except', 'amity', 'benchley', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'consisted', 'carrying', 'boat', 'abortive', 'gettysburg', 'ulysses', 'albury', 'veracruz', 'firing', 'dominican', 'redford', 'clarified', 'humiliation', 'prerogative', 'temperance', 'tightened', 'home', 'rome', 'neoliberal', 'unrecognized', 'overboard', 'identified', 'yeoman', 'bottens', 'ultimately', 'via', 'ask', 'grattan', 'latin', 'dispersed', 'being', 'scanned', 'rombaut', 'laid', 'briggs', 'professorship', 'pretoria', 'near', 'conceived', 'radioisotope', 'abauzit', 'golfer', 'tend', 'feuilletoirs', 'businesspeople', 'huge', 'leiva', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'lectured', 'protect', 'galley', 'watkins', 'bleeding', 'oak', 'victoria', 'universidad', 'ended', 'diable', 'blackout', 'resulting', 'sacrificing', 'dobre', 'erdenwallen', 'ainger', 'ó', 'boucomont', 'fresse', 'midwife', 'aimed', 'jacobus', 'baptism', 'spraying', 'shelby', 'intending', 'watched', 'clinique', 'schneekluth', 'yet', 'bonpland', 'defended', 'favri', 'pastry', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'fomenting', 'witch', 'charette', 'imposition', 'storrs', 'jurieu', 'legalistic', 'casualty', 'revere', 'crippled', 'yes', 'specialised', 'waar', 'kellyism', 'settler', 'labelye', 'midnight', 'anja', 'revelation', 'gomarus', 'fallot', 'downed', 'lundberg', 'tchuruk', 'disseminated', 'office', 'wartime', 'earthly', 'spinoza', 'earl', 'blon', 'weekend', 'upholding', 'shipping', 'trainee', 'rallied', 'vermenoux', 'afford', 'richardot', 'vereker', 'judgment', 'abandonment', 'associate', 'ridicule', 'ordering', 'instance', 'pallenberg', 'whether', 'border', 'bombardment', 'maritain', 'debrett', 'situ', 'bombarded', 'isabella', 'theologically', 'stimulus', 'mcculloch', 'sailing', 'rumania', 'erie', 'round', 'communion', 'douce', 'nachruhm', 'religieux', 'snoop', 'single', 'shocked', 'elfried', 'crater', 'lyric', 'oder', 'maligning', 'disadvantage', 'frka', 'huygens', 'intolerable', 'schaar', 'lohse', 'murville', 'fictional', 'conventional', 'bondsman', 'cons ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens in the vocabulary of spacy:  15413
# SPACY TOKENS
#  {'originator', 'mainly', 'sweden', 'seller', 'technocrat', 'rothe', 'mazel', 'doumergue', 'delano', 'watt', 'exist', 'joining', 'pictorial', 'planningchanges', 'decommissioned', 'infrastructure', 'miserable', 'matthew', 'jessie', 'günther', 'typical', 'blindness', 'eisengold', 'demonstrates', 'moscova', 'valdo', 'moral', 'defensive', 'necessitating', 'philanthropic', 'guiding', 'visuals', 'something', 'architectural', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'bhagavad', 'konstanze', 'possibly', 'criollo', 'considered', 'theologian', 'mouvement', 'miscellany', 'mythological', 'alarmed', 'contract', 'financing', 'duchy', 'fetishism', 'applicable', 'jew', 'showmanship', 'liger', 'advocate', 'chatelain', 'hatt', 'gastigny', 'volunteered', 'killed', 'constipation', 'phoned', 'steady', 'invokes', 'existed', 'diego', 'workmanship', 'drunk', 'tributary', 'golf', 'hospitalised', 'penitent', 'schipper', 'cazenove', 'detroit', 'clooney', 'allied', 'miscarriage', 'video', 'regarded', 'antisemitism', 'hammett', 'manières', 'priority', 'impressionism', 'eradicate', 'frankenstein', 'gregson', 'clement', 'istoric', 'deed', 'murder', 'estrangement', 'official', 'lag', 'iberia', 'aerial', 'asphyxiation', 'hierarchy', 'wish', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'rearrangement', 'commentary', 'greenback', 'stepdaughter', 'felony', 'competing', 'feux', 'laroon', 'königsberg', 'chabrol', 'besides', 'filming', 'displeasure', 'greatest', 'opposite', 'analyze', 'pierre', 'setback', 'resurrected', 'pavilion', 'bischoff', 'sandra', 'durham', 'polity', 'pettigrew', 'heath', 'anticipate', 'selig', 'sub', 'ambrose', 'tie', 'equaled', 'charmes', 'combat', 'commonly', 'impartial', 'hold', 'walter', 'aurélie', 'marchand', 'soberingly', 'peugeot', 'meanwhile', 'storm', 'retracted', 'japanese', 'eugenie', 'chevalier', 'efficiently', 'journal', 'expense', 'failure', 'evaluation', 'except', 'amity', 'benchley', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'consisted', 'carrying', 'boat', 'abortive', 'gettysburg', 'ulysses', 'albury', 'veracruz', 'firing', 'dominican', 'redford', 'clarified', 'humiliation', 'denominational', 'prerogative', 'temperance', 'tightened', 'home', 'rome', 'neoliberal', 'unrecognized', 'overboard', 'identified', 'yeoman', 'bottens', 'ultimately', 'via', 'ask', 'grattan', 'latin', 'dispersed', 'being', 'scanned', 'rombaut', 'laid', 'briggs', 'professorship', 'pretoria', 'near', 'conceived', 'radioisotope', 'abauzit', 'golfer', 'tend', 'feuilletoirs', 'businesspeople', 'huge', 'leiva', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'lectured', 'protect', 'galley', 'watkins', 'bleeding', 'oak', 'victoria', 'universidad', 'ended', 'diable', 'blackout', 'resulting', 'sacrificing', 'dobre', 'erdenwallen', 'ainger', 'ó', 'boucomont', 'fresse', 'midwife', 'aimed', 'jacobus', 'baptism', 'spraying', 'shelby', 'intending', 'watched', 'clinique', 'schneekluth', 'yet', 'bonpland', 'defended', 'favri', 'pastry', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'fomenting', 'witch', 'charette', 'imposition', 'storrs', 'jurieu', 'legalistic', 'casualty', 'revere', 'crippled', 'yes', 'specialised', 'waar', 'kellyism', 'settler', 'labelye', 'midnight', 'anja', 'revelation', 'gomarus', 'fallot', 'downed', 'lundberg', 'tchuruk', 'disseminated', 'office', 'wartime', 'earthly', 'spinoza', 'earl', 'blon', 'weekend', 'upholding', 'shipping', 'trainee', 'rallied', 'vermenoux', 'afford', 'richardot', 'vereker', 'judgment', 'abandonment', 'associate', 'ridicule', 'ordering', 'instance', 'pallenberg', 'whether', 'border', 'bombardment', 'maritain', 'debrett', 'situ', 'bombarded', 'isabella', 'theologically', 'stimulus', 'mcculloch', 'sailing', 'rumania', 'erie', 'round', 'communion', 'douce', 'nachruhm', 'religieux', 'snoop', 'single', 'shocked', 'elfried', 'crater', 'lyric', 'oder', 'maligning', 'disadvantage', 'frka', 'huygens', 'intolerable', 'schaar', 'lohse', 'murville', 'fictional', 'conventional', ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens in the vocabulary of both libraries:  15349
# Tokens in the vocabulary of both libraries
#  {'originator', 'mainly', 'sweden', 'seller', 'technocrat', 'rothe', 'mazel', 'doumergue', 'delano', 'watt', 'exist', 'joining', 'pictorial', 'planningchanges', 'decommissioned', 'infrastructure', 'miserable', 'matthew', 'jessie', 'günther', 'typical', 'blindness', 'eisengold', 'demonstrates', 'moscova', 'valdo', 'moral', 'defensive', 'necessitating', 'philanthropic', 'guiding', 'visuals', 'something', 'architectural', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'bhagavad', 'konstanze', 'possibly', 'criollo', 'considered', 'theologian', 'mouvement', 'miscellany', 'mythological', 'alarmed', 'contract', 'financing', 'duchy', 'fetishism', 'applicable', 'jew', 'showmanship', 'liger', 'gastigny', 'phoned', 'constipation', 'advocate', 'chatelain', 'hatt', 'volunteered', 'killed', 'steady', 'invokes', 'existed', 'diego', 'workmanship', 'drunk', 'tributary', 'golf', 'hospitalised', 'penitent', 'schipper', 'cazenove', 'detroit', 'clooney', 'allied', 'miscarriage', 'video', 'regarded', 'antisemitism', 'hammett', 'manières', 'priority', 'impressionism', 'eradicate', 'frankenstein', 'gregson', 'clement', 'istoric', 'deed', 'murder', 'estrangement', 'official', 'lag', 'iberia', 'aerial', 'asphyxiation', 'hierarchy', 'wish', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'rearrangement', 'commentary', 'greenback', 'stepdaughter', 'felony', 'competing', 'feux', 'laroon', 'königsberg', 'chabrol', 'besides', 'filming', 'displeasure', 'greatest', 'opposite', 'analyze', 'pierre', 'setback', 'resurrected', 'pavilion', 'bischoff', 'sandra', 'durham', 'polity', 'pettigrew', 'heath', 'anticipate', 'selig', 'sub', 'ambrose', 'tie', 'equaled', 'charmes', 'combat', 'commonly', 'impartial', 'hold', 'walter', 'aurélie', 'marchand', 'soberingly', 'peugeot', 'meanwhile', 'storm', 'retracted', 'japanese', 'eugenie', 'chevalier', 'efficiently', 'journal', 'expense', 'failure', 'evaluation', 'except', 'amity', 'benchley', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'consisted', 'carrying', 'boat', 'abortive', 'gettysburg', 'ulysses', 'albury', 'veracruz', 'firing', 'dominican', 'redford', 'clarified', 'humiliation', 'prerogative', 'temperance', 'tightened', 'home', 'rome', 'neoliberal', 'unrecognized', 'overboard', 'identified', 'yeoman', 'bottens', 'ultimately', 'via', 'ask', 'grattan', 'latin', 'dispersed', 'being', 'scanned', 'rombaut', 'laid', 'briggs', 'professorship', 'pretoria', 'near', 'conceived', 'radioisotope', 'abauzit', 'golfer', 'tend', 'feuilletoirs', 'businesspeople', 'huge', 'leiva', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'lectured', 'protect', 'galley', 'watkins', 'bleeding', 'oak', 'universidad', 'diable', 'ended', 'blackout', 'victoria', 'resulting', 'sacrificing', 'dobre', 'erdenwallen', 'ainger', 'ó', 'boucomont', 'midwife', 'aimed', 'baptism', 'jacobus', 'fresse', 'spraying', 'shelby', 'intending', 'watched', 'clinique', 'schneekluth', 'yet', 'bonpland', 'pastry', 'defended', 'favri', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'fomenting', 'witch', 'charette', 'imposition', 'storrs', 'jurieu', 'legalistic', 'casualty', 'revere', 'crippled', 'yes', 'specialised', 'waar', 'kellyism', 'settler', 'labelye', 'midnight', 'anja', 'revelation', 'gomarus', 'fallot', 'downed', 'lundberg', 'tchuruk', 'disseminated', 'office', 'spinoza', 'wartime', 'earthly', 'earl', 'blon', 'weekend', 'upholding', 'shipping', 'trainee', 'rallied', 'vermenoux', 'afford', 'richardot', 'vereker', 'judgment', 'abandonment', 'associate', 'ridicule', 'ordering', 'instance', 'pallenberg', 'whether', 'border', 'bombardment', 'maritain', 'debrett', 'situ', 'bombarded', 'isabella', 'theologically', 'stimulus', 'mcculloch', 'sailing', 'rumania', 'erie', 'round', 'communion', 'douce', 'nachruhm', 'religieux', 'snoop', 'single', 'shocked', 'elfried', 'crater', 'lyric', 'oder', 'maligning', 'disadvantage', 'frka', 'huygens', 'intolerable', 'schaar', 'lohse', 'murville', 'fictional', 'conventional', 'bondsman', 'cons ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of all tokens:  15446
# All tokens
#  {'mainly', 'sweden', 'rothe', 'mazel', 'doumergue', 'exist', 'pictorial', 'jessie', 'günther', 'eisengold', 'defensive', 'moral', 'philanthropic', 'visuals', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'konstanze', 'criollo', 'theologian', 'mythological', 'alarmed', 'duchy', 'applicable', 'phoned', 'killed', 'invokes', 'diego', 'penitent', 'detroit', 'allied', 'video', 'regarded', 'priority', 'impressionism', 'frankenstein', 'clement', 'istoric', 'estrangement', 'official', 'aerial', 'hierarchy', 'rearrangement', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'greenback', 'königsberg', 'chabrol', 'besides', 'analyze', 'resurrected', 'pavilion', 'sandra', 'durham', 'polity', 'selig', 'tie', 'charmes', 'combat', 'commonly', 'hold', 'walter', 'soberingly', 'marchand', 'peugeot', 'meanwhile', 'storm', 'japanese', 'chevalier', 'failure', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'carrying', 'abortive', 'ulysses', 'veracruz', 'firing', 'dominican', 'humiliation', 'temperance', 'home', 'rome', 'yeoman', 'latin', 'dispersed', 'being', 'professorship', 'conceived', 'golfer', 'tend', 'businesspeople', 'huge', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'galley', 'watkins', 'ended', 'ainger', 'baptism', 'boucomont', 'fresse', 'jacobus', 'shelby', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'witch', 'imposition', 'jurieu', 'casualty', 'revere', 'specialised', 'settler', 'labelye', 'revelation', 'gomarus', 'disseminated', 'wartime', 'earl', 'upholding', 'vermenoux', 'afford', 'richardot', 'judgment', 'ridicule', 'pallenberg', 'whether', 'border', 'debrett', 'situ', 'mcculloch', 'rumania', 'erie', 'nachruhm', 'single', 'shocked', 'intolerable', 'fictional', 'conventional', 'musée', 'ladybug', 'sat', 'reconciling', 'dem', 'polish', 'publication', 'mall', 'eclectic', 'omohundro', 'vai', 'hendon', 'estienne', 'périgord', 'verve', 'rowed', 'dugout', 'fracturing', 'donation', 'access', 'torch', 'adult', 'majendie', 'cavalry', 'onésime', 'interactive', 'prominence', 'postscript', 'ba', 'simcoe', 'used', 'peschier', 'buccaneering', 'appreciated', 'rousset', 'jimmy', 'erroneous', 'dieu', 'mediating', 'guilhem', 'provence', 'chrestomathie', 'hope', 'malcolm', 'brussels', 'masures', 'jain', 'attis', 'staple', 'kitchen', 'toward', 'tvpa', 'hannelies', 'firework', 'attorney', 'uprising', 'overcome', 'numbering', 'thucydide', 'campbell', 'hunting', 'revitalize', 'advises', 'poujade', 'stevens', 'summarize', 'experimentation', 'cuvier', 'swinge', 'hot', 'colloquium', 'juneteenth', 'degree', 'harperperennial', 'lifelong', 'portland', 'chart', 'carl', 'secondary', 'surveyed', 'castres', 'heiress', 'pastoralist', 'dirichlet', 'magdeburg', 'botha', 'diminished', 'distinction', 'publius', 'discharged', 'pluviôse', 'font', 'introduction', 'stalemated', 'montserrat', 'gag', 'papier', 'inconclusive', 'jézéquel', 'intensely', 'ringleader', 'smallness', 'moderne', 'salem', 'shirt', 'brittanique', 'september', 'tribune', 'desborough', 'policing', 'cullmann', 'annals', 'ether', 'guesting', 'santo', 'betray', 'rochester', 'dancing', 'dissolution', 'investing', 'british', 'cousin', 'audition', 'san', 'alcatel', 'aiding', 'battlefield', 'substantive', 'discogs', 'isabelle', 'duress', 'balladur', 'idealized', 'elizabeth', 'barranquilla', 'agony', 'nolan', 'deflected', 'disciplinary', 'heidelberg', 'riorteau', 'hart', 'byles', 'decided', 'anna', 'psychiatrische', 'condemnation', 'ratification', 'skyrocketed', 'traditionalist', 'kulturbesitz', 'geographia', 'endorsement', 'relocate', 'detail', 'instead', 'inducing', 'hailed', 'repeated', 'piggy', 'high', 'taught', 'pupil', 'believed', 'compass', 'ever', 'coupled', 'qui', 'environmentalist', 'bei', 'entitled', 'constitution', 'cheated', 'casalis', 'indebtedness', 'tacitly', 'royal', 'impression', 'helper', 'reunite', 'complete', 'moldavia', 'despicable', 'instructing', 'oust', 'bellermann', 'nosed', 'disguised', 'prosecute', 'edgar', 'foreordination', 'poultry', ' ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens that only in the vocabulary of stanza:  33
# UNIQUE FOR STANZA {'ven', 'lehrgeschwader', 'terre', 'muskel', 'veneration', 'abʁaam', 'cannot', 'fm', 'schlacht', 'gen', 'bros', 'clausonne', 'alɛ', 'nx', 'portland', 'oung', 'covid', 'im', 'lovin', 'orc', 'igny', 'ejg', 'wd', 'beast', 'fatty', 'gonna', 'wed', 'lemay', 'acknowledgement', 'lenisambulatrix', 'sl', 'hegel', 'kelleyism'}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens that only in the vocabulary of spacy:  64
# UNIQUE FOR SPACY {'headliner', 'sr', 'drs', 'integrated', 'pan', 'imperialist', 'räuber', 'esq', 'maj', 'machiavelli', 'th', 'nhl', 'inter', 'xxxvii', 'repr', 'colonialist', 'micro', 'lt', 'dixon', 'amoebic', 'denominational', 'ref', 'accor', 'w', 'masonic', 'mason', 'éd', 'ser', 'zee', 'wm', 'tennesseethe', 'sen', 'ziggy', 'duplessis', 'mid', 'sgt', 'sayn', 'gon', 'economistdr', 'caputo', 'na', 'etc', 'col', 'geo', 'organism', 'manoeuvrable', 'presenter', 'tr', 'doo', 'conformist', 'olio', 'nebraska', 'nrs', 'roovers', 'patriates', 'vivisection', 'semi', 'authoritarian', 'wittgenstein', 'negotiable', 'germanist', 'xvime', 'laplace', 'deathsin'}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Top 30 most common tokens for stanza [('de', 1737), ('french', 1452), ('pastor', 1415), ('american', 1178), ('war', 908), ('british', 862), ('jean', 819), ('south', 762), ('first', 704), ('state', 639), ('died', 571), ('work', 546), ('new', 541), ('african', 513), ('john', 493), ('family', 473), ('pierre', 468), ('huguenot', 464), ('le', 440), ('german', 434), ('theologian', 431), ('slave', 428), ('slavery', 428), ('la', 427), ('member', 413), ('du', 401), ('jacques', 398), ('martyr', 397), ('galland', 395), ('day', 383)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Top 30 most common tokens for spacy [('de', 1738), ('french', 1452), ('pastor', 1415), ('american', 1182), ('war', 931), ('british', 863), ('jean', 819), ('south', 761), ('first', 704), ('state', 635), ('died', 571), ('work', 546), ('new', 541), ('slavery', 522), ('african', 513), ('john', 494), ('family', 474), ('pierre', 468), ('huguenot', 464), ('le', 440), ('german', 435), ('theologian', 431), ('slave', 430), ('la', 427), ('founder', 424), ('member', 413), ('du', 401), ('jacques', 398), ('martyr', 397), ('galland', 391)]

# %% [markdown]
# ### 2.2.2 SharedTokensInSentences
#
# Now we will work with shared segmented sentences.

# %%
shared_sent_df = pd.read_csv("shared_sentences.csv")

# %%
shared_sent_df.head(5)
# Out:
#                                     shared_sentences
# 0  An attempt to resupply the fort on January 9, ...
# 1  The second was a civil war with all thirteen s...
# 2  The Grimké sisters' public speaking played a c...
# 3  The debates were covered in detail by American...
# 4  Galland was upset about the director's decisio...

# %%
def tokenize_after_segmentation(shared_sent_df):
    
    nlp1 = stanza.Pipeline(lang='en', processors='tokenize')
    nlp2 = spacy.load('en_core_web_sm')
    
    shared_sent_df['tokens_stanza'] = shared_sent_df['shared_sentences'].apply(lambda x: [token.text for sentence in nlp1(x).sentences for token in sentence.tokens])
    shared_sent_df['tokens_spacy'] = shared_sent_df['shared_sentences'].apply(lambda x: [token.text for token in nlp2(x)])
    
    shared_sent_df["cleaned_tokens_stanza"] = shared_sent_df["tokens_stanza"].apply(lambda x: preprocess(x))
    shared_sent_df["cleaned_tokens_spacy"] = shared_sent_df["tokens_spacy"].apply(lambda x: preprocess(x))
    
    shared_sent_df["tokens_occurence_stanza"] = shared_sent_df["cleaned_tokens_stanza"].apply(lambda x: collections.Counter(x))
    shared_sent_df["tokens_occurence_spacy"] = shared_sent_df["cleaned_tokens_spacy"].apply(lambda x: collections.Counter(x))
    

    
     # creating vocabularies of unique tokens for each library
    vocab_stanza = set(token for tokens in df['tokens_stanza'] for token in tokens)
    vocab_spacy = set(token for tokens in df['tokens_spacy'] for token in tokens)
    
    # tokens which simalteneously present in both vocabularies
    both_vocab_tokens = vocab_stanza.intersection(vocab_spacy)
    
    # all tokens which present in both vocabularies
    common_tokens_stanza = vocab_stanza.union(vocab_spacy)
    
    only_spacy_tokens = vocab_spacy.difference(vocab_stanza)
    only_stanza_tokens = vocab_stanza.difference(vocab_spacy)
    
    print("-----------------" * 10)
    print("Number of tokens in the vocabulary of stanza: ", len(vocab_stanza))
    print("STANZA TOKENS\n", vocab_stanza) 
    
    print("-----------------" * 10)
    print("Number of tokens in the vocabulary of spacy: ", len(vocab_spacy))
    print("SPACY TOKENS\n", vocab_spacy)
    
    print("-----------------" * 10)
    print("Number of tokens in the vocabulary of both libraries: ", len(both_vocab_tokens))
    print("Tokens in the vocabulary of both libraries\n", both_vocab_tokens)
    
    print("-----------------" * 10)
    print("Number of all tokens: ", len(common_tokens_stanza))
    print("All tokens\n", common_tokens_stanza)
    
    print("-----------------" * 10)
    print("Number of tokens that only in the vocabulary of stanza: ", len(only_stanza_tokens))
    print("UNIQUE FOR STANZA", only_stanza_tokens)
    
    print("-----------------" * 10)
    print("Number of tokens that only in the vocabulary of spacy: ", len(only_spacy_tokens))
    print("UNIQUE FOR SPACY", only_spacy_tokens)
    
    
    print("-----------------" * 10)
    print("Top 30 most common tokens for stanza", df["tokens_occurence_stanza"].sum().most_common(30))
    
    print("-----------------" * 10)
    print("Top 30 most common tokens for spacy", df["tokens_occurence_spacy"].sum().most_common(30))
    
    df.to_csv("tokenization_after_segmentation.csv", index=False)
    return df

# %%
df_tokens = tokenize_after_segmentation(shared_sent_df)
# Out:
# 2023-05-14 04:50:30 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json: 216kB [00:00, 31.1MB/s]
# 2023-05-14 04:50:30 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2023-05-14 04:50:30 INFO: Using device: cpu
# 2023-05-14 04:50:30 INFO: Loading: tokenize
# 2023-05-14 04:50:30 INFO: Done loading processors!
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens in the vocabulary of stanza:  15382
# STANZA TOKENS
#  {'originator', 'mainly', 'sweden', 'seller', 'technocrat', 'rothe', 'mazel', 'doumergue', 'delano', 'watt', 'exist', 'joining', 'pictorial', 'planningchanges', 'decommissioned', 'infrastructure', 'miserable', 'matthew', 'jessie', 'günther', 'typical', 'blindness', 'eisengold', 'demonstrates', 'moscova', 'valdo', 'moral', 'defensive', 'necessitating', 'philanthropic', 'guiding', 'visuals', 'something', 'architectural', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'bhagavad', 'konstanze', 'possibly', 'criollo', 'considered', 'theologian', 'mouvement', 'miscellany', 'mythological', 'alarmed', 'contract', 'financing', 'duchy', 'fetishism', 'applicable', 'jew', 'showmanship', 'liger', 'advocate', 'chatelain', 'hatt', 'gastigny', 'volunteered', 'killed', 'constipation', 'phoned', 'steady', 'invokes', 'existed', 'diego', 'workmanship', 'drunk', 'tributary', 'golf', 'hospitalised', 'penitent', 'schipper', 'cazenove', 'detroit', 'clooney', 'allied', 'miscarriage', 'video', 'regarded', 'antisemitism', 'hammett', 'manières', 'priority', 'impressionism', 'eradicate', 'frankenstein', 'gregson', 'clement', 'istoric', 'deed', 'murder', 'estrangement', 'official', 'lag', 'iberia', 'aerial', 'asphyxiation', 'hierarchy', 'wish', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'rearrangement', 'commentary', 'greenback', 'stepdaughter', 'felony', 'competing', 'feux', 'laroon', 'königsberg', 'chabrol', 'besides', 'filming', 'displeasure', 'greatest', 'opposite', 'analyze', 'pierre', 'setback', 'resurrected', 'pavilion', 'bischoff', 'sandra', 'durham', 'polity', 'pettigrew', 'heath', 'anticipate', 'selig', 'sub', 'ambrose', 'tie', 'equaled', 'charmes', 'combat', 'commonly', 'impartial', 'hold', 'walter', 'aurélie', 'marchand', 'soberingly', 'peugeot', 'meanwhile', 'storm', 'retracted', 'japanese', 'eugenie', 'chevalier', 'efficiently', 'journal', 'expense', 'failure', 'evaluation', 'except', 'amity', 'benchley', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'consisted', 'carrying', 'boat', 'abortive', 'gettysburg', 'ulysses', 'albury', 'veracruz', 'firing', 'dominican', 'redford', 'clarified', 'humiliation', 'prerogative', 'temperance', 'tightened', 'home', 'rome', 'neoliberal', 'unrecognized', 'overboard', 'identified', 'yeoman', 'bottens', 'ultimately', 'via', 'ask', 'grattan', 'latin', 'dispersed', 'being', 'scanned', 'rombaut', 'laid', 'briggs', 'professorship', 'pretoria', 'near', 'conceived', 'radioisotope', 'abauzit', 'golfer', 'tend', 'feuilletoirs', 'businesspeople', 'huge', 'leiva', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'lectured', 'protect', 'galley', 'watkins', 'bleeding', 'oak', 'victoria', 'universidad', 'ended', 'diable', 'blackout', 'resulting', 'sacrificing', 'dobre', 'erdenwallen', 'ainger', 'ó', 'boucomont', 'fresse', 'midwife', 'aimed', 'jacobus', 'baptism', 'spraying', 'shelby', 'intending', 'watched', 'clinique', 'schneekluth', 'yet', 'bonpland', 'defended', 'favri', 'pastry', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'fomenting', 'witch', 'charette', 'imposition', 'storrs', 'jurieu', 'legalistic', 'casualty', 'revere', 'crippled', 'yes', 'specialised', 'waar', 'kellyism', 'settler', 'labelye', 'midnight', 'anja', 'revelation', 'gomarus', 'fallot', 'downed', 'lundberg', 'tchuruk', 'disseminated', 'office', 'wartime', 'earthly', 'spinoza', 'earl', 'blon', 'weekend', 'upholding', 'shipping', 'trainee', 'rallied', 'vermenoux', 'afford', 'richardot', 'vereker', 'judgment', 'abandonment', 'associate', 'ridicule', 'ordering', 'instance', 'pallenberg', 'whether', 'border', 'bombardment', 'maritain', 'debrett', 'situ', 'bombarded', 'isabella', 'theologically', 'stimulus', 'mcculloch', 'sailing', 'rumania', 'erie', 'round', 'communion', 'douce', 'nachruhm', 'religieux', 'snoop', 'single', 'shocked', 'elfried', 'crater', 'lyric', 'oder', 'maligning', 'disadvantage', 'frka', 'huygens', 'intolerable', 'schaar', 'lohse', 'murville', 'fictional', 'conventional', 'bondsman', 'cons ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens in the vocabulary of spacy:  15413
# SPACY TOKENS
#  {'originator', 'mainly', 'sweden', 'seller', 'technocrat', 'rothe', 'mazel', 'doumergue', 'delano', 'watt', 'exist', 'joining', 'pictorial', 'planningchanges', 'decommissioned', 'infrastructure', 'miserable', 'matthew', 'jessie', 'günther', 'typical', 'blindness', 'eisengold', 'demonstrates', 'moscova', 'valdo', 'moral', 'defensive', 'necessitating', 'philanthropic', 'guiding', 'visuals', 'something', 'architectural', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'bhagavad', 'konstanze', 'possibly', 'criollo', 'considered', 'theologian', 'mouvement', 'miscellany', 'mythological', 'alarmed', 'contract', 'financing', 'duchy', 'fetishism', 'applicable', 'jew', 'showmanship', 'liger', 'advocate', 'chatelain', 'hatt', 'gastigny', 'volunteered', 'killed', 'constipation', 'phoned', 'steady', 'invokes', 'existed', 'diego', 'workmanship', 'drunk', 'tributary', 'golf', 'hospitalised', 'penitent', 'schipper', 'cazenove', 'detroit', 'clooney', 'allied', 'miscarriage', 'video', 'regarded', 'antisemitism', 'hammett', 'manières', 'priority', 'impressionism', 'eradicate', 'frankenstein', 'gregson', 'clement', 'istoric', 'deed', 'murder', 'estrangement', 'official', 'lag', 'iberia', 'aerial', 'asphyxiation', 'hierarchy', 'wish', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'rearrangement', 'commentary', 'greenback', 'stepdaughter', 'felony', 'competing', 'feux', 'laroon', 'königsberg', 'chabrol', 'besides', 'filming', 'displeasure', 'greatest', 'opposite', 'analyze', 'pierre', 'setback', 'resurrected', 'pavilion', 'bischoff', 'sandra', 'durham', 'polity', 'pettigrew', 'heath', 'anticipate', 'selig', 'sub', 'ambrose', 'tie', 'equaled', 'charmes', 'combat', 'commonly', 'impartial', 'hold', 'walter', 'aurélie', 'marchand', 'soberingly', 'peugeot', 'meanwhile', 'storm', 'retracted', 'japanese', 'eugenie', 'chevalier', 'efficiently', 'journal', 'expense', 'failure', 'evaluation', 'except', 'amity', 'benchley', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'consisted', 'carrying', 'boat', 'abortive', 'gettysburg', 'ulysses', 'albury', 'veracruz', 'firing', 'dominican', 'redford', 'clarified', 'humiliation', 'denominational', 'prerogative', 'temperance', 'tightened', 'home', 'rome', 'neoliberal', 'unrecognized', 'overboard', 'identified', 'yeoman', 'bottens', 'ultimately', 'via', 'ask', 'grattan', 'latin', 'dispersed', 'being', 'scanned', 'rombaut', 'laid', 'briggs', 'professorship', 'pretoria', 'near', 'conceived', 'radioisotope', 'abauzit', 'golfer', 'tend', 'feuilletoirs', 'businesspeople', 'huge', 'leiva', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'lectured', 'protect', 'galley', 'watkins', 'bleeding', 'oak', 'victoria', 'universidad', 'ended', 'diable', 'blackout', 'resulting', 'sacrificing', 'dobre', 'erdenwallen', 'ainger', 'ó', 'boucomont', 'fresse', 'midwife', 'aimed', 'jacobus', 'baptism', 'spraying', 'shelby', 'intending', 'watched', 'clinique', 'schneekluth', 'yet', 'bonpland', 'defended', 'favri', 'pastry', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'fomenting', 'witch', 'charette', 'imposition', 'storrs', 'jurieu', 'legalistic', 'casualty', 'revere', 'crippled', 'yes', 'specialised', 'waar', 'kellyism', 'settler', 'labelye', 'midnight', 'anja', 'revelation', 'gomarus', 'fallot', 'downed', 'lundberg', 'tchuruk', 'disseminated', 'office', 'wartime', 'earthly', 'spinoza', 'earl', 'blon', 'weekend', 'upholding', 'shipping', 'trainee', 'rallied', 'vermenoux', 'afford', 'richardot', 'vereker', 'judgment', 'abandonment', 'associate', 'ridicule', 'ordering', 'instance', 'pallenberg', 'whether', 'border', 'bombardment', 'maritain', 'debrett', 'situ', 'bombarded', 'isabella', 'theologically', 'stimulus', 'mcculloch', 'sailing', 'rumania', 'erie', 'round', 'communion', 'douce', 'nachruhm', 'religieux', 'snoop', 'single', 'shocked', 'elfried', 'crater', 'lyric', 'oder', 'maligning', 'disadvantage', 'frka', 'huygens', 'intolerable', 'schaar', 'lohse', 'murville', 'fictional', 'conventional', ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens in the vocabulary of both libraries:  15349
# Tokens in the vocabulary of both libraries
#  {'originator', 'mainly', 'sweden', 'seller', 'technocrat', 'rothe', 'mazel', 'doumergue', 'delano', 'watt', 'exist', 'joining', 'pictorial', 'planningchanges', 'decommissioned', 'infrastructure', 'miserable', 'matthew', 'jessie', 'günther', 'typical', 'blindness', 'eisengold', 'demonstrates', 'moscova', 'valdo', 'moral', 'defensive', 'necessitating', 'philanthropic', 'guiding', 'visuals', 'something', 'architectural', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'bhagavad', 'konstanze', 'possibly', 'criollo', 'considered', 'theologian', 'mouvement', 'miscellany', 'mythological', 'alarmed', 'contract', 'financing', 'duchy', 'fetishism', 'applicable', 'jew', 'showmanship', 'liger', 'gastigny', 'phoned', 'constipation', 'advocate', 'chatelain', 'hatt', 'volunteered', 'killed', 'steady', 'invokes', 'existed', 'diego', 'workmanship', 'drunk', 'tributary', 'golf', 'hospitalised', 'penitent', 'schipper', 'cazenove', 'detroit', 'clooney', 'allied', 'miscarriage', 'video', 'regarded', 'antisemitism', 'hammett', 'manières', 'priority', 'impressionism', 'eradicate', 'frankenstein', 'gregson', 'clement', 'istoric', 'deed', 'murder', 'estrangement', 'official', 'lag', 'iberia', 'aerial', 'asphyxiation', 'hierarchy', 'wish', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'rearrangement', 'commentary', 'greenback', 'stepdaughter', 'felony', 'competing', 'feux', 'laroon', 'königsberg', 'chabrol', 'besides', 'filming', 'displeasure', 'greatest', 'opposite', 'analyze', 'pierre', 'setback', 'resurrected', 'pavilion', 'bischoff', 'sandra', 'durham', 'polity', 'pettigrew', 'heath', 'anticipate', 'selig', 'sub', 'ambrose', 'tie', 'equaled', 'charmes', 'combat', 'commonly', 'impartial', 'hold', 'walter', 'aurélie', 'marchand', 'soberingly', 'peugeot', 'meanwhile', 'storm', 'retracted', 'japanese', 'eugenie', 'chevalier', 'efficiently', 'journal', 'expense', 'failure', 'evaluation', 'except', 'amity', 'benchley', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'consisted', 'carrying', 'boat', 'abortive', 'gettysburg', 'ulysses', 'albury', 'veracruz', 'firing', 'dominican', 'redford', 'clarified', 'humiliation', 'prerogative', 'temperance', 'tightened', 'home', 'rome', 'neoliberal', 'unrecognized', 'overboard', 'identified', 'yeoman', 'bottens', 'ultimately', 'via', 'ask', 'grattan', 'latin', 'dispersed', 'being', 'scanned', 'rombaut', 'laid', 'briggs', 'professorship', 'pretoria', 'near', 'conceived', 'radioisotope', 'abauzit', 'golfer', 'tend', 'feuilletoirs', 'businesspeople', 'huge', 'leiva', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'lectured', 'protect', 'galley', 'watkins', 'bleeding', 'oak', 'universidad', 'diable', 'ended', 'blackout', 'victoria', 'resulting', 'sacrificing', 'dobre', 'erdenwallen', 'ainger', 'ó', 'boucomont', 'midwife', 'aimed', 'baptism', 'jacobus', 'fresse', 'spraying', 'shelby', 'intending', 'watched', 'clinique', 'schneekluth', 'yet', 'bonpland', 'pastry', 'defended', 'favri', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'fomenting', 'witch', 'charette', 'imposition', 'storrs', 'jurieu', 'legalistic', 'casualty', 'revere', 'crippled', 'yes', 'specialised', 'waar', 'kellyism', 'settler', 'labelye', 'midnight', 'anja', 'revelation', 'gomarus', 'fallot', 'downed', 'lundberg', 'tchuruk', 'disseminated', 'office', 'spinoza', 'wartime', 'earthly', 'earl', 'blon', 'weekend', 'upholding', 'shipping', 'trainee', 'rallied', 'vermenoux', 'afford', 'richardot', 'vereker', 'judgment', 'abandonment', 'associate', 'ridicule', 'ordering', 'instance', 'pallenberg', 'whether', 'border', 'bombardment', 'maritain', 'debrett', 'situ', 'bombarded', 'isabella', 'theologically', 'stimulus', 'mcculloch', 'sailing', 'rumania', 'erie', 'round', 'communion', 'douce', 'nachruhm', 'religieux', 'snoop', 'single', 'shocked', 'elfried', 'crater', 'lyric', 'oder', 'maligning', 'disadvantage', 'frka', 'huygens', 'intolerable', 'schaar', 'lohse', 'murville', 'fictional', 'conventional', 'bondsman', 'cons ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of all tokens:  15446
# All tokens
#  {'mainly', 'sweden', 'rothe', 'mazel', 'doumergue', 'exist', 'pictorial', 'jessie', 'günther', 'eisengold', 'defensive', 'moral', 'philanthropic', 'visuals', 'tabernacle', 'irresponsible', 'nazism', 'elevate', 'konstanze', 'criollo', 'theologian', 'mythological', 'alarmed', 'duchy', 'applicable', 'phoned', 'killed', 'invokes', 'diego', 'penitent', 'detroit', 'allied', 'video', 'regarded', 'priority', 'impressionism', 'frankenstein', 'clement', 'istoric', 'estrangement', 'official', 'aerial', 'hierarchy', 'rearrangement', 'plaintiff', 'rheumatism', 'schuster', 'quadraturis', 'greenback', 'königsberg', 'chabrol', 'besides', 'analyze', 'resurrected', 'pavilion', 'sandra', 'durham', 'polity', 'selig', 'tie', 'charmes', 'combat', 'commonly', 'hold', 'walter', 'soberingly', 'marchand', 'peugeot', 'meanwhile', 'storm', 'japanese', 'chevalier', 'failure', 'lobby', 'election', 'follower', 'restraining', 'announcing', 'disciple', 'group', 'carrying', 'abortive', 'ulysses', 'veracruz', 'firing', 'dominican', 'humiliation', 'temperance', 'home', 'rome', 'yeoman', 'latin', 'dispersed', 'being', 'professorship', 'conceived', 'golfer', 'tend', 'businesspeople', 'huge', 'someone', 'gallery', 'aufrère', 'fc', 'trobe', 'galley', 'watkins', 'ended', 'ainger', 'baptism', 'boucomont', 'fresse', 'jacobus', 'shelby', 'judaism', 'tuckahoe', 'hunter', 'rossel', 'witch', 'imposition', 'jurieu', 'casualty', 'revere', 'specialised', 'settler', 'labelye', 'revelation', 'gomarus', 'disseminated', 'wartime', 'earl', 'upholding', 'vermenoux', 'afford', 'richardot', 'judgment', 'ridicule', 'pallenberg', 'whether', 'border', 'debrett', 'situ', 'mcculloch', 'rumania', 'erie', 'nachruhm', 'single', 'shocked', 'intolerable', 'fictional', 'conventional', 'musée', 'ladybug', 'sat', 'reconciling', 'dem', 'polish', 'publication', 'mall', 'eclectic', 'omohundro', 'vai', 'hendon', 'estienne', 'périgord', 'verve', 'rowed', 'dugout', 'fracturing', 'donation', 'access', 'torch', 'adult', 'majendie', 'cavalry', 'onésime', 'interactive', 'prominence', 'postscript', 'ba', 'simcoe', 'used', 'peschier', 'buccaneering', 'appreciated', 'rousset', 'jimmy', 'erroneous', 'dieu', 'mediating', 'guilhem', 'provence', 'chrestomathie', 'hope', 'malcolm', 'brussels', 'masures', 'jain', 'attis', 'staple', 'kitchen', 'toward', 'tvpa', 'hannelies', 'firework', 'attorney', 'uprising', 'overcome', 'numbering', 'thucydide', 'campbell', 'hunting', 'revitalize', 'advises', 'poujade', 'stevens', 'summarize', 'experimentation', 'cuvier', 'swinge', 'hot', 'colloquium', 'juneteenth', 'degree', 'harperperennial', 'lifelong', 'portland', 'chart', 'carl', 'secondary', 'surveyed', 'castres', 'heiress', 'pastoralist', 'dirichlet', 'magdeburg', 'botha', 'diminished', 'distinction', 'publius', 'discharged', 'pluviôse', 'font', 'introduction', 'stalemated', 'montserrat', 'gag', 'papier', 'inconclusive', 'jézéquel', 'intensely', 'ringleader', 'smallness', 'moderne', 'salem', 'shirt', 'brittanique', 'september', 'tribune', 'desborough', 'policing', 'cullmann', 'annals', 'ether', 'guesting', 'santo', 'betray', 'rochester', 'dancing', 'dissolution', 'investing', 'british', 'cousin', 'audition', 'san', 'alcatel', 'aiding', 'battlefield', 'substantive', 'discogs', 'isabelle', 'duress', 'balladur', 'idealized', 'elizabeth', 'barranquilla', 'agony', 'nolan', 'deflected', 'disciplinary', 'heidelberg', 'riorteau', 'hart', 'byles', 'decided', 'anna', 'psychiatrische', 'condemnation', 'ratification', 'skyrocketed', 'traditionalist', 'kulturbesitz', 'geographia', 'endorsement', 'relocate', 'detail', 'instead', 'inducing', 'hailed', 'repeated', 'piggy', 'high', 'taught', 'pupil', 'believed', 'compass', 'ever', 'coupled', 'qui', 'environmentalist', 'bei', 'entitled', 'constitution', 'cheated', 'casalis', 'indebtedness', 'tacitly', 'royal', 'impression', 'helper', 'reunite', 'complete', 'moldavia', 'despicable', 'instructing', 'oust', 'bellermann', 'nosed', 'disguised', 'prosecute', 'edgar', 'foreordination', 'poultry', ' ...
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens that only in the vocabulary of stanza:  33
# UNIQUE FOR STANZA {'ven', 'lehrgeschwader', 'terre', 'muskel', 'veneration', 'abʁaam', 'cannot', 'fm', 'schlacht', 'gen', 'bros', 'clausonne', 'alɛ', 'nx', 'portland', 'oung', 'covid', 'im', 'lovin', 'orc', 'igny', 'ejg', 'wd', 'beast', 'fatty', 'gonna', 'wed', 'lemay', 'acknowledgement', 'lenisambulatrix', 'sl', 'hegel', 'kelleyism'}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Number of tokens that only in the vocabulary of spacy:  64
# UNIQUE FOR SPACY {'headliner', 'sr', 'drs', 'integrated', 'pan', 'imperialist', 'räuber', 'esq', 'maj', 'machiavelli', 'th', 'nhl', 'inter', 'xxxvii', 'repr', 'colonialist', 'micro', 'lt', 'dixon', 'amoebic', 'denominational', 'ref', 'accor', 'w', 'masonic', 'mason', 'éd', 'ser', 'zee', 'wm', 'tennesseethe', 'sen', 'ziggy', 'duplessis', 'mid', 'sgt', 'sayn', 'gon', 'economistdr', 'caputo', 'na', 'etc', 'col', 'geo', 'organism', 'manoeuvrable', 'presenter', 'tr', 'doo', 'conformist', 'olio', 'nebraska', 'nrs', 'roovers', 'patriates', 'vivisection', 'semi', 'authoritarian', 'wittgenstein', 'negotiable', 'germanist', 'xvime', 'laplace', 'deathsin'}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Top 30 most common tokens for stanza [('de', 1737), ('french', 1452), ('pastor', 1415), ('american', 1178), ('war', 908), ('british', 862), ('jean', 819), ('south', 762), ('first', 704), ('state', 639), ('died', 571), ('work', 546), ('new', 541), ('african', 513), ('john', 493), ('family', 473), ('pierre', 468), ('huguenot', 464), ('le', 440), ('german', 434), ('theologian', 431), ('slave', 428), ('slavery', 428), ('la', 427), ('member', 413), ('du', 401), ('jacques', 398), ('martyr', 397), ('galland', 395), ('day', 383)]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Top 30 most common tokens for spacy [('de', 1738), ('french', 1452), ('pastor', 1415), ('american', 1182), ('war', 931), ('british', 863), ('jean', 819), ('south', 761), ('first', 704), ('state', 635), ('died', 571), ('work', 546), ('new', 541), ('slavery', 522), ('african', 513), ('john', 494), ('family', 474), ('pierre', 468), ('huguenot', 464), ('le', 440), ('german', 435), ('theologian', 431), ('slave', 430), ('la', 427), ('founder', 424), ('member', 413), ('du', 401), ('jacques', 398), ('martyr', 397), ('galland', 391)]
